# %%
import numpy as np

# %%
x = np.ones(4)

# %%
print x
# Out:
# [ 1.  1.  1.  1.]

# %%
x = x.reshape(4,1)

# %%
print x
# Out:
# [[ 1.]
#  [ 1.]
#  [ 1.]
#  [ 1.]]

# %%
import pandas
print x.ravel()
print x.reshape(-1)
# Out:
# [ 1.  1.  1.  1.]
# [ 1.  1.  1.  1.]

# %%
print x.iloc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-f0021e9b964f> in <module>()
# ----> 1 print x.iloc()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'
